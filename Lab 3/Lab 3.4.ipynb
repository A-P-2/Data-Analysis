# %%
# !pip install scikit-learn==0.22.2
# Out:
# Requirement already satisfied: scikit-learn==0.22.2 in c:\users\nekit\anaconda3\lib\site-packages (0.22.2)
# Requirement already satisfied: numpy>=1.11.0 in c:\users\nekit\anaconda3\lib\site-packages (from scikit-learn==0.22.2) (1.20.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\nekit\anaconda3\lib\site-packages (from scikit-learn==0.22.2) (1.0.1)
# Requirement already satisfied: scipy>=0.17.0 in c:\users\nekit\anaconda3\lib\site-packages (from scikit-learn==0.22.2) (1.6.2)

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

from yellowbrick.cluster import KElbowVisualizer
from yellowbrick.cluster import SilhouetteVisualizer

# %% [markdown]
# # Составление набора данных

# %%
X, y_true = make_blobs(n_samples=300, centers=5,
                       cluster_std=0.85, random_state=9)
plt.scatter(X[:, 0], X[:, 1], c=y_true, s=50, cmap='viridis');

# %% [markdown]
# # Оценка качества кластеризации

# %% [markdown]
# **Метод локтя**

# %%
model = KMeans()
visualizer = KElbowVisualizer(model, k=(2, 12))

visualizer.fit(X)
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# **Силуэтный коэффицент**

# %%
for i in [2, 3, 5, 7]:
    model = KMeans(i)
    visualizer = SilhouetteVisualizer(model)

    visualizer.fit(X)
    visualizer.show()
